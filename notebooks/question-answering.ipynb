# %%
from deeppavlov import build_model, configs

# %%
model = build_model(configs.squad.squad_ru_torch_bert, download=True)
# Out:
# /home/yakov/PycharmProjects/yandex-profi-se-semifinal-2022/venv/lib/python3.8/site-packages/cryptography/hazmat/backends/openssl/x509.py:14: CryptographyDeprecationWarning: This version of cryptography contains a temporary pyOpenSSL fallback path. Upgrade pyOpenSSL now.
#   warnings.warn(
# 2022-03-11 10:13:54.998 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/v1/squad/squad_ru_torch_bert.tar.gz download because of matching hashes
# [nltk_data] Downloading package punkt to /home/yakov/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/yakov/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     /home/yakov/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /home/yakov/nltk_data...
# ...

# %%
def model_inference(text, question):
    return model([text], [question])

# %%
texts = ['''Иван родился в семье великого князя Московского Василия III (Рюриковича) и
         литовской княжны Елены Глинской в 1530 году, но уже в 1533 году Иван потерял отца, 
         а в 1538 году умерла и мать. После смерти отца маленький Иван IV был свидетелем ожесточенной
         борьбы между боярскими кланами Вельских и Шуйских, что стало причиной подозрительной мнительности
         царя и недоверия к боярам.''',
         '''Санкт‑Петербург, расположенный на берегу Финского залива Балтийского моря, является европейскими
         воротами России, ее стратегическим центром, непосредственно граничащим со странами Европейского Союза.'''
        ]

questions = ['В каком году родился Иван Грозный?', 'Где расположен Санкт-Петербург?']

# %%
for text, question in zip(texts, questions):
    print(model_inference(text, question))
